# %% [markdown]
# ### Problem Statement
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
#     - Which variables are significant in predicting the price of a car
#     - How well those variables describe the price of a car
#
# Based on various market surveys, the consulting firm has gathered a large dataset of different types of cars across the Americal market.

# %% [markdown]
# ### Business Goal
#
# Model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# ## Import Python Libraries
# Setting up the Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.svm import SVR
from sklearn import metrics

# %%
sns.set_style('darkgrid')
pd.set_option('display.max_columns', 30)
#np.random.seed(4)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Understanding the Data

# %%
df = pd.read_csv("CarPrice_Assignment.csv")
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
# 1  convertible        rwd          front       88.6      168.8      64.1
# 2    hatchback        rwd          front       94.5      171.2      65.5
# 3        sedan        fwd          front       99.8      176.6      66.2
# 4        sedan        4wd          front       99.4      176.6      66.4
#
#    carheight  curbweight enginetype cylindernumber  enginesize fuelsystem  \
# 0       48.8        2548       dohc           four         130       mpfi
# 1       48.8        2548       dohc           four         130       mpfi
# 2       52.4        2823       ohcv            six         152       mpfi
# 3       54.3        2337        ohc           four         109       mpfi
# 4       54.3        2824        ohc           five         136       mpfi
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 0       3.47    2.68               9.0         111     5000       21
# 1       3.47    2.68               9.0         111     5000       21
# 2       2.68    3.47               9.0         154     5000       19
# 3       3.19    3.40              10.0         102     5500       24
# 4       3.19    3.40               8.0         115     5500       18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0

# %%
df.columns #given features that affect price
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (205, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %% [markdown]
# ## Data Preprocessing

# %%
cars = df.copy()

# %%
brand = cars['CarName'].apply(lambda x : x.split(' ')[0]) #split company name from carname
cars.insert(3,"CompanyName", brand)

# %%
cars.drop(["CarName"], axis = 1, inplace = True)

# %%
cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %% [markdown]
# ###### Spelling errors in 'CompanyName' column

# %%
cars.CompanyName = cars.CompanyName.str.lower()

#replace with correct spellings
cars.CompanyName.replace('maxda','mazda', inplace = True)
cars.CompanyName.replace('porcshce','porsche', inplace = True)
cars.CompanyName.replace('toyouta','toyota', inplace = True)
cars.CompanyName.replace('vokswagen','volkswagen', inplace = True)
cars.CompanyName.replace('vw','volkswagen', inplace = True)

cars.CompanyName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
cars.loc[cars.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CompanyName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []

# %%
#No Duplicated values found
cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %% [markdown]
# Checking for Null Values

# %%
cars.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CompanyName         0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
cars[['doornumber','cylindernumber']].head()
# Out:
#   doornumber cylindernumber
# 0        two           four
# 1        two           four
# 2        two            six
# 3       four           four
# 4       four           five

# %%
from word2number import w2n
#convert number words to numeric digits

for i in range(len(cars.doornumber)):
    cars.doornumber[i] = w2n.word_to_num(cars.doornumber[i])
    cars.cylindernumber[i] = w2n.word_to_num(cars.cylindernumber[i])
cars[['doornumber','cylindernumber']].head()
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_24600/1766775706.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.doornumber[i] = w2n.word_to_num(cars.doornumber[i])
# C:\Users\DELL\AppData\Local\Temp/ipykernel_24600/1766775706.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars.cylindernumber[i] = w2n.word_to_num(cars.cylindernumber[i])
#   doornumber cylindernumber
# 0          2              4
# 1          2              4
# 2          2              6
# 3          4              4
# 4          4              5

# %% [markdown]
# ## Understanding and Visualising Data

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
sns.kdeplot(cars.price, fill = 'true')
plt.subplot(1,2,2)
sns.boxplot(cars.price)
plt.show()

# %% [markdown]
# Inference :
#
# 1. The plot is right-skewed, meaning that the most prices in the dataset are low(Below 15,000).
# 2. The data points are far spread out from the mean, which indicates a high variance in the car prices.(85% of the prices are below 18,500, whereas the remaining 15% are between 18,500 and 45,400.)

# %%
cars.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
#Feature Generation
cars['fueleconomy'] = (0.55 * cars['citympg']) + (0.45 * cars['highwaympg'])

# %%
cars1 = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase','fueleconomy',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'carlength','carwidth']]

plt.figure(figsize = (15,15))
sns.heatmap(cars1.corr(), annot = True, cmap = "PiYG")
plt.show()

# %% [markdown]
# ### Visualising Categorical data

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CompanyName       205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
#  26  fueleconomy       205 non-null    float64
# dtypes: float64(9), int64(8), object(10)
# memory usage: 43.4+ KB

# %%
plt.figure(figsize=(22,5))
plt.subplot(1,2,1)

sns.countplot(cars.CompanyName).set_title('Companies')
plt.xticks(rotation = 90)
plt.subplot(1,2,2)
kd = pd.DataFrame(cars.groupby(['CompanyName'])['price'].mean().sort_values(ascending = False))
kd = kd.reset_index()
sns.barplot(x = kd.CompanyName, y = kd.price).set_title("Average Price Vs Company")
plt.xticks(rotation = 90)
plt.ylabel('Average Price')
plt.show()

# %% [markdown]
#  Inference:
#
#  1. `Toyota` makes the most buyed cars with `Average Price` around `10000`.
#  2. `Jaguar`, `Buick`, and `Porsche` seems to have highest average price.

# %%
plt.figure(figsize=(24,15))
plt.subplot(2,4,1)
sns.countplot(cars.fueltype).set_title('Fueltypes')

plt.subplot(2,4,2)
sns.countplot(cars.enginetype).set_title('Enginetype')

plt.subplot(2,4,3)
sns.countplot(cars.carbody).set_title('Cartype')
plt.xticks(rotation = 90)

plt.subplot(2,4,4)
sns.countplot(cars.doornumber).set_title('Doornumber')


plt.subplot(2,4,5)
sns.boxplot(x = cars.fueltype, y = cars.price).set_title('Fueltype vs Price')

plt.subplot(2,4,6)
kd = pd.DataFrame(cars.groupby(['enginetype'])['price'].mean())
kd = pd.DataFrame({'x': cars['enginetype'].unique(), 'price': kd['price']})
sns.barplot(x = kd['x'], y = kd['price']).set_title('Enginetype vs Average Price')
plt.xlabel('enginetype')
plt.ylabel('Average Price')

plt.subplot(2,4,7)
kd = pd.DataFrame(cars.groupby(['carbody'])['price'].mean())
kd = pd.DataFrame({'x': cars['carbody'].unique(), 'price': kd['price']})
sns.barplot(x = kd['x'], y = kd['price']).set_title('Cartype vs Average Price')
plt.xlabel('carbody')
plt.ylabel('Average Price')
plt.xticks(rotation = 90)


plt.subplot(2,4,8)
sns.boxplot(x = cars.doornumber, y = cars.price).set_title('Door Number vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Inference:
#
# 1. Number of `gas` fueled cars are more than `diesel` fueled.
# 2. Median price of `gas` fueled cars is lesser than `diesel` cars.
# 3. `ohc` is the most preferred engine type with average price around 15000.
# 4. `sedan` is the top car type prefered. `convertible` and `hatchback` cars have higher average price
# 5. Cars with 4 `doors` were preferred over 2 doors.

# %%
plt.figure(figsize = (20,13))

plt.subplot(2,3,1)
sns.countplot(cars.symboling).set_title('Symboling')

plt.subplot(2,3,2)
sns.countplot(cars.aspiration).set_title('Aspiration')

plt.subplot(2,3,3)
sns.countplot(cars.drivewheel).set_title('Drivewheel')

plt.subplot(2,3,4)
sns.boxplot(x = cars.symboling, y = cars.price).set_title('Symboling vs Price')

plt.subplot(2,3,5)
sns.boxplot(x = cars.aspiration, y = cars.price).set_title('Aspiration vs Price')

plt.subplot(2,3,6)
sns.boxplot(x = cars.drivewheel, y = cars.price).set_title('Drivewheel vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference:
#
# 1. Mostly sold cars have `symboling` values between `0` and `1`.
# 2. Cars with lower symboling values have higher price.
# 3. Aspiration with `turbo` have higher interquartile range of price than `std`
# 4. Most high range cars seems to prefer `rwd`(rear-wheel-drive) drivewheel.

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.countplot(cars.fuelsystem).set_title('Fuelsystem')

plt.subplot(2,2,3)
sns.boxplot(x = 'fuelsystem', y = 'price', data = cars).set_title('Fuelsystem vs Price')

plt.subplot(2,2,2)
sns.countplot(cars.enginelocation).set_title('Engine Location')

plt.subplot(2,2,4)
sns.boxplot(x = cars.enginelocation, y = cars.price).set_title('Engine Location vs Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# Inference :
#
# 1. `mpfi` and `2bbl` are most common type of fuel systems. `mpfi` and `idi` having the highest price range. But there are few data for other categories to derive any meaningful inference.
# 2. Most cars have enginelocation as `front`. Very few datapoints for further infeence to be made.

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CompanyName       205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
#  26  fueleconomy       205 non-null    float64
# dtypes: float64(9), int64(8), object(10)
# memory usage: 43.4+ KB

# %% [markdown]
# ### Visualising Numeric Data

# %%
def pp(x,y,z):
    sns.pairplot(cars, x_vars=[x,y,z], y_vars='price',size=4, aspect=1, kind='scatter', hue = 'drivewheel')
    plt.show()

pp('enginesize', 'boreratio', 'stroke')
pp('compressionratio', 'horsepower', 'peakrpm')
pp('wheelbase', 'citympg', 'highwaympg')
plt.tight_layout()

# %% [markdown]
# Inference:
# 1. `enginesize`, `boreratio`, `horsepower`, `wheelbase` - have a significant positive correlation with price.
# 2. `citympg`, `highwaympg` - have a significant negative correlation with price.

# %%
def scatter(x,fig):
    plt.subplot(2,2,fig)
    sns.scatterplot(cars[x],cars['price'], hue = cars['enginetype'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(20,12))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)
plt.tight_layout()
plt.show()

# %% [markdown]
#  Inference :
#
# 1. `carwidth`, `carlength` and `curbweight` seems to have a poitive correlation with `price`.
# 2. `carheight` doesn't show any significant trend with price.

# %%
plt.figure(figsize = (15,6))
plt.subplot(1,2,1)
sns.scatterplot(x = cars.fueleconomy, y = cars.price, hue = cars.horsepower).set_title('Fuel Economy vs Price')

plt.subplot(1,2,2)
sns.scatterplot(x = cars.enginesize, y = cars.price, hue = cars.horsepower).set_title('Enginesize vs Price')
plt.show()

# %% [markdown]
#  Inference :
#
# 1. `fueleconomy` has an obvious `negative correlation` with price and is significant.
# 2. Cars with more `horsepower` have higher `price` and low `fueleconomy`.
# 3. `enginesize` is highly correlated with `price`

# %%
plt.figure(figsize = (35,35))
cars1 = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase','fueleconomy',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 'carlength','carwidth']]
sns.pairplot(cars1, diag_kind = 'kde', palette = "Set2")
plt.show()

# %% [markdown]
# # Building Machine Learning Models

# %%
cars.head()
# Out:
#    car_ID  symboling CompanyName fueltype aspiration doornumber      carbody  \
# 0       1          3  alfa-romeo      gas        std        two  convertible
# 1       2          3  alfa-romeo      gas        std        two  convertible
# 2       3          1  alfa-romeo      gas        std        two    hatchback
# 3       4          2        audi      gas        std       four        sedan
# 4       5          2        audi      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  carheight  \
# 0        rwd          front       88.6      168.8      64.1       48.8
# 1        rwd          front       88.6      168.8      64.1       48.8
# 2        rwd          front       94.5      171.2      65.5       52.4
# 3        fwd          front       99.8      176.6      66.2       54.3
# 4        4wd          front       99.4      176.6      66.4       54.3
#
#    curbweight enginetype cylindernumber  enginesize fuelsystem  boreratio  \
# 0        2548       dohc           four         130       mpfi       3.47
# 1        2548       dohc           four         130       mpfi       3.47
# 2        2823       ohcv            six         152       mpfi       2.68
# 3        2337        ohc           four         109       mpfi       3.19
# 4        2824        ohc           five         136       mpfi       3.19
#
#    stroke  compressionratio  horsepower  peakrpm  citympg  highwaympg    price
# 0    2.68               9.0         111     5000       21          27  13495.0
# 1    2.68               9.0         111     5000       21          27  16500.0
# 2    3.47               9.0         154     5000       19          26  16500.0
# 3    3.40              10.0         102     5500       24          30  13950.0
# 4    3.40               8.0         115     5500       18          22  17450.0

# %% [markdown]
# Convert Categorical Attributes to Numerical features by taking dummy variables

# %%
cars2 = cars.copy()
Y = cars.price
#cars2.drop(['car_ID','price'], axis = 'columns', inplace = True)
cars2 = pd.get_dummies(cars2)
cars2.drop(['car_ID','price'], axis = 'columns', inplace = True)
cars2.shape
# Out:
# (205, 74)

# %% [markdown]
# Using StandardScaler to remove the mean and scale each feature/variable to unit variance

# %%
slr = StandardScaler()
X_scaled = slr.fit_transform(cars2)

# %%
X_scaled
# Out:
# array([[ 1.74347043, -1.6907718 , -0.42652147, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [ 1.74347043, -1.6907718 , -0.42652147, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [ 0.133509  , -0.70859588, -0.23151305, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        ...,
#        [-1.47645244,  1.72187336,  1.19854871, ...,  1.08666971,
#         -0.21428571, -0.070014  ],
#        [-1.47645244,  1.72187336,  1.19854871, ..., -0.92024282,
#         -0.21428571, -0.070014  ],
#        [-1.47645244,  1.72187336,  1.19854871, ...,  1.08666971,
#         -0.21428571, -0.070014  ]])

# %% [markdown]
# Dimensionality Reduction using Principal Component Analysis(PCA)

# %%
pca = PCA(0.95) #retaining 95% of information
cars_pca = pca.fit_transform(X_scaled)
cars_pca.shape
# Out:
# (205, 35)

# %% [markdown]
# Splitting dataset into training and test sets

# %%
np.random.seed(9)
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled,Y,test_size = 0.3)
#X_train, X_test, Y_train, Y_test = train_test_split(cars_pca,Y,test_size = 0.3, random_state= 9)

# %%
def print_metrics(y_test,y_pred):
  print('Mean Absolute Error:', round(metrics.mean_absolute_error(y_test, y_pred),2))
  print('Mean Squared Error:', round(metrics.mean_squared_error(y_test, y_pred),2))
  print('Root Mean Squared Error:', round(np.sqrt(metrics.mean_squared_error(y_test, y_pred)),2))
  print('Mean Absolute Percentage Error:', round(metrics.mean_absolute_percentage_error(y_test, y_pred),2))
  print('R2 score:', round(metrics.r2_score(y_pred,y_test),2))

# %% [markdown]
# ### Since the target variable(`price`) is continuos which implies that regression will be the best suited technique for making prediction.
# We built 5 different regression models to compare the accuracies and chose one with best performance. These models include sklearn's, `LinearRegression()`, `DecisionTreeRegressor()`,`RandomForestRegressor()`, and XGBoost's(Extreme Gradient Boost) `XGBRegressor`. We also built a `Deep Neural Network` with 2 hidden layers and linear activation function.

# %% [markdown]
# ### Model 1: Multiple Linear Regression
#   - It is a statistical technique that uses several explanatory variables to predict the outcome of a response variable.
#   - In this section we use sklearn's `LinearRegression()` method to build model and predict the target variable.

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
print("Goodness of fit: " + str(round((lr.score(X_train,Y_train)*100),2)) + "%")
y_pred1 = lr.predict(X_test)
print("Model Score: "+ str(round(lr.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 96.83%
# Model Score: 92.75%

# %%
print_metrics(Y_test,y_pred1)
# Out:
# Mean Absolute Error: 1613.5
# Mean Squared Error: 4443660.48
# Root Mean Squared Error: 2108.0
# Mean Absolute Percentage Error: 0.14
# R2 score: 0.94

# %%
plt.scatter(X_test[:,11], Y_test, color = 'red')
plt.scatter(X_test[:,11], y_pred1, color = 'green')
plt.show()

# %% [markdown]
# ### Model 2: Decision Tree Regression

# %%
#regressor = DecisionTreeRegressor(random_state=10, max_depth=4)
regressor = DecisionTreeRegressor( max_depth=4)

regressor.fit(X_train, Y_train)
y_pred2 = regressor.predict(X_test)
print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 95.14%
# Model Score: 88.2%

# %%
print_metrics(Y_test,y_pred2)
# Out:
# Mean Absolute Error: 1813.25
# Mean Squared Error: 7235251.61
# Root Mean Squared Error: 2689.84
# Mean Absolute Percentage Error: 0.14
# R2 score: 0.91

# %%
plt.scatter(X_test[:,10], Y_test, color = 'red')
plt.scatter(X_test[:,10], y_pred2, color = 'green')
plt.show()

# %% [markdown]
# ### Model 3. Random Forest Regression

# %%
#regressor = RandomForestRegressor(random_state=9)
regressor = RandomForestRegressor()
regressor.fit(X_train, Y_train)
y_pred3 = regressor.predict(X_test)

print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# Goodness of fit: 98.69%
# Model Score: 93.78%

# %%
print_metrics(Y_test,y_pred3)
# Out:
# Mean Absolute Error: 1281.13
# Mean Squared Error: 3812013.65
# Root Mean Squared Error: 1952.44
# Mean Absolute Percentage Error: 0.1
# R2 score: 0.95

# %%
plt.scatter(X_test[:,12], Y_test, color = 'red')
plt.scatter(X_test[:,12], y_pred3, color = 'green')
plt.show()

# %% [markdown]
# ### Model 4. XGBRegressor

# %%
regressor = XGBRegressor()
regressor.fit(X_train, Y_train)
y_pred4 = regressor.predict(X_test)

print("Goodness of fit: " + str(round((regressor.score(X_train,Y_train)*100),2)) + "%")
print("Model Score: "+ str(round(regressor.score(X_test,Y_test)*100,2)) + "%")
# Out:
# [09:11:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Goodness of fit: 99.31%
# Model Score: 92.45%

# %%
print_metrics(Y_test,y_pred4)
# Out:
# Mean Absolute Error: 1352.34
# Mean Squared Error: 4629922.31
# Root Mean Squared Error: 2151.73
# Mean Absolute Percentage Error: 0.1
# R2 score: 0.94

# %%
plt.scatter(X_test[:,16], Y_test, color = 'red')
plt.scatter(X_test[:,16], y_pred4, color = 'green')
plt.show()

# %% [markdown]
# ### Model 5: Neural Network Based Regression

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten

# %%
NNmodel = Sequential()

# The Input Layer :
NNmodel.add(Dense(128, kernel_initializer='normal',input_dim = X_train.shape[1], activation='relu'))

# The Hidden Layers :
NNmodel.add(Dense(256, kernel_initializer='normal',activation='relu'))
NNmodel.add(Dense(256, kernel_initializer='normal',activation='relu'))
#NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# The Output Layer :
NNmodel.add(Dense(1, kernel_initializer='normal',activation='linear'))

# Compile the network :
NNmodel.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NNmodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               9600
#
#  dense_13 (Dense)            (None, 256)               33024
#
#  dense_14 (Dense)            (None, 256)               65792
#
#  dense_15 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 108,673
# Trainable params: 108,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %%
NNmodel.fit(X_train, Y_train, epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# Epoch 1/500
# 1/4 [======>.......................] - ETA: 1s - loss: 14471.1602 - mean_absolute_error: 14471.1602
# Epoch 1: val_loss improved from inf to 13223.62305, saving model to Weights-001--13223.62305.hdf5
# 4/4 [==============================] - 1s 69ms/step - loss: 13636.0234 - mean_absolute_error: 13636.0234 - val_loss: 13223.6230 - val_mean_absolute_error: 13223.6230
# Epoch 2/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12383.4922 - mean_absolute_error: 12383.4922
# Epoch 2: val_loss improved from 13223.62305 to 13222.27734, saving model to Weights-002--13222.27734.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 13635.1357 - mean_absolute_error: 13635.1357 - val_loss: 13222.2773 - val_mean_absolute_error: 13222.2773
# Epoch 3/500
# 1/4 [======>.......................] - ETA: 0s - loss: 15199.1074 - mean_absolute_error: 15199.1074
# Epoch 3: val_loss improved from 13222.27734 to 13219.70020, saving model to Weights-003--13219.70020.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 13633.4717 - mean_absolute_error: 13633.4717 - val_loss: 13219.7002 - val_mean_absolute_error: 13219.7002
# Epoch 4/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14251.1016 - mean_absolute_error: 14251.1016
# Epoch 4: val_loss improved from 13219.70020 to 13215.06641, saving model to Weights-004--13215.06641.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 13630.1553 - mean_absolute_error: 13630.1553 - val_loss: 13215.0664 - val_mean_absolute_error: 13215.0664
# Epoch 5/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11929.8135 - mean_absolute_error: 11929.8135
# Epoch 5: val_loss improved from 13215.06641 to 13207.24805, saving model to Weights-005--13207.24805.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 13623.9385 - mean_absolute_error: 13623.9385 - val_loss: 13207.2480 - val_mean_absolute_error: 13207.2480
# Epoch 6/500
# 1/4 [======>.......................] - ETA: 0s - loss: 15383.0957 - mean_absolute_error: 15383.0957
# Epoch 6: val_loss improved from 13207.24805 to 13194.43359, saving model to Weights-006--13194.43359.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 13613.2324 - mean_absolute_error: 13613.2324 - val_loss: 13194.4336 - val_mean_absolute_error: 13194.4336
# Epoch 7/500
# 1/4 [======>.......................] - ETA: 0s - loss: 11818.4883 - mean_absolute_error: 11818.4883
# Epoch 7: val_loss improved from 13194.43359 to 13174.40723, saving model to Weights-007--13174.40723.hdf5
# 4/4 [==============================] - 0s 26ms/step - loss: 13595.3955 - mean_absolute_error: 13595.3955 - val_loss: 13174.4072 - val_mean_absolute_error: 13174.4072
# Epoch 8/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13633.9707 - mean_absolute_error: 13633.9707
# Epoch 8: val_loss improved from 13174.40723 to 13143.87207, saving model to Weights-008--13143.87207.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 13567.2070 - mean_absolute_error: 13567.2070 - val_loss: 13143.8721 - val_mean_absolute_error: 13143.8721
# Epoch 9/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14381.2090 - mean_absolute_error: 14381.2090
# Epoch 9: val_loss improved from 13143.87207 to 13098.61230, saving model to Weights-009--13098.61230.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 13522.5527 - mean_absolute_error: 13522.5527 - val_loss: 13098.6123 - val_mean_absolute_error: 13098.6123
# Epoch 10/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14915.2764 - mean_absolute_error: 14915.2764
# Epoch 10: val_loss improved from 13098.61230 to 13033.62500, saving model to Weights-010--13033.62500.hdf5
# 4/4 [==============================] - 0s 26ms/step - loss: 13458.2021 - mean_absolute_error: 13458.2021 - val_loss: 13033.6250 - val_mean_absolute_error: 13033.6250
# Epoch 11/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13073.7832 - mean_absolute_error: 13073.7832
# Epoch 11: val_loss improved from 13033.62500 to 12939.78125, saving model to Weights-011--12939.78125.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 13359.4629 - mean_absolute_error: 13359.4629 - val_loss: 12939.7812 - val_mean_absolute_error: 12939.7812
# Epoch 12/500
# 1/4 [======>.......................] - ETA: 0s - loss: 14297.8730 - mean_absolute_error: 14297.8730
# Epoch 12: val_loss improved from 12939.78125 to 12810.21289, saving model to Weights-012--12810.21289.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 13218.8623 - mean_absolute_error: 13218.8623 - val_loss: 12810.2129 - val_mean_absolute_error: 12810.2129
# Epoch 13/500
# 1/4 [======>.......................] - ETA: 0s - loss: 17033.2480 - mean_absolute_error: 17033.2480
# Epoch 13: val_loss improved from 12810.21289 to 12634.57129, saving model to Weights-013--12634.57129.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 13032.8643 - mean_absolute_error: 13032.8643 - val_loss: 12634.5713 - val_mean_absolute_error: 12634.5713
# Epoch 14/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13900.4912 - mean_absolute_error: 13900.4912
# Epoch 14: val_loss improved from 12634.57129 to 12399.12109, saving model to Weights-014--12399.12109.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 12762.4805 - mean_absolute_error: 12762.4805 - val_loss: 12399.1211 - val_mean_absolute_error: 12399.1211
# Epoch 15/500
# 1/4 [======>.......................] - ETA: 0s - loss: 15165.9033 - mean_absolute_error: 15165.9033
# Epoch 15: val_loss improved from 12399.12109 to 12090.56445, saving model to Weights-015--12090.56445.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 12402.4385 - mean_absolute_error: 12402.4385 - val_loss: 12090.5645 - val_mean_absolute_error: 12090.5645
# Epoch 16/500
# 1/4 [======>.......................] - ETA: 0s - loss: 13201.0508 - mean_absolute_error: 13201.0508
# Epoch 16: val_loss improved from 12090.56445 to 11684.60449, saving model to Weights-016--11684.60449.hdf5
# 4/4 [==============================] - 0s 36ms/step - loss: 11933.5068 - mean_absolute_error: 11933.5068 - val_loss: 11684.6045 - val_mean_absolute_error: 11684.6045
# Epoch 17/500
# 1/4 [======>.......................] - ETA: 0s - loss: 12468.5039 - mean_absolute_error: 12468.5039
# Epoch 17: val_loss improved from 11684.60449 to 11161.27148, saving model to Weights-017--11161.27148.hdf5
# 4/4 [==============================] - 0s 21ms/step - loss: 11317.6494 - mean_absolute_error: 11317.6494 - val_loss: 11161.2715 - val_mean_absolute_error: 11161.2715
# Epoch 18/500
# 1/4 [======>.......................] - ETA: 0s - loss: 10933.9023 - mean_absolute_error: 10933.9023
# Epoch 18: val_loss improved from 11161.27148 to 10496.84277, saving model to Weights-018--10496.84277.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 10501.1465 - mean_absolute_error: 10501.1465 - val_loss: 10496.8428 - val_mean_absolute_error: 10496.8428
# Epoch 19/500
# 1/4 [======>.......................] - ETA: 0s - loss: 9539.5645 - mean_absolute_error: 9539.5645
# Epoch 19: val_loss improved from 10496.84277 to 9660.02539, saving model to Weights-019--9660.02539.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 9499.5947 - mean_absolute_error: 9499.5947 - val_loss: 9660.0254 - val_mean_absolute_error: 9660.0254
# Epoch 20/500
# 1/4 [======>.......................] - ETA: 0s - loss: 10981.1680 - mean_absolute_error: 10981.1680
# Epoch 20: val_loss improved from 9660.02539 to 8755.42383, saving model to Weights-020--8755.42383.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 8253.2568 - mean_absolute_error: 8253.2568 - val_loss: 8755.4238 - val_mean_absolute_error: 8755.4238
# Epoch 21/500
# 1/4 [======>.......................] - ETA: 0s - loss: 6779.2861 - mean_absolute_error: 6779.2861
# Epoch 21: val_loss improved from 8755.42383 to 7808.76709, saving model to Weights-021--7808.76709.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 6890.4673 - mean_absolute_error: 6890.4673 - val_loss: 7808.7671 - val_mean_absolute_error: 7808.7671
# Epoch 22/500
# 1/4 [======>.......................] - ETA: 0s - loss: 5879.0347 - mean_absolute_error: 5879.0347
# Epoch 22: val_loss improved from 7808.76709 to 7159.75537, saving model to Weights-022--7159.75537.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 5728.1240 - mean_absolute_error: 5728.1240 - val_loss: 7159.7554 - val_mean_absolute_error: 7159.7554
# Epoch 23/500
# 1/4 [======>.......................] - ETA: 0s - loss: 5580.2363 - mean_absolute_error: 5580.2363
# Epoch 23: val_loss improved from 7159.75537 to 6705.29541, saving model to Weights-023--6705.29541.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 4833.4355 - mean_absolute_error: 4833.4355 - val_loss: 6705.2954 - val_mean_absolute_error: 6705.2954
# Epoch 24/500
# 1/4 [======>.......................] - ETA: 0s - loss: 4159.7646 - mean_absolute_error: 4159.7646
# Epoch 24: val_loss improved from 6705.29541 to 6302.57275, saving model to Weights-024--6302.57275.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 4122.1855 - mean_absolute_error: 4122.1855 - val_loss: 6302.5728 - val_mean_absolute_error: 6302.5728
# Epoch 25/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3034.2578 - mean_absolute_error: 3034.2578
# Epoch 25: val_loss improved from 6302.57275 to 5921.72314, saving model to Weights-025--5921.72314.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 3831.1609 - mean_absolute_error: 3831.1609 - val_loss: 5921.7231 - val_mean_absolute_error: 5921.7231
# Epoch 26/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3051.4248 - mean_absolute_error: 3051.4248
# Epoch 26: val_loss improved from 5921.72314 to 5561.37549, saving model to Weights-026--5561.37549.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 3490.7188 - mean_absolute_error: 3490.7188 - val_loss: 5561.3755 - val_mean_absolute_error: 5561.3755
# Epoch 27/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3096.9944 - mean_absolute_error: 3096.9944
# Epoch 27: val_loss improved from 5561.37549 to 5263.16113, saving model to Weights-027--5263.16113.hdf5
# 4/4 [==============================] - 0s 36ms/step - loss: 3077.7241 - mean_absolute_error: 3077.7241 - val_loss: 5263.1611 - val_mean_absolute_error: 5263.1611
# Epoch 28/500
# 1/4 [======>.......................] - ETA: 0s - loss: 3700.0630 - mean_absolute_error: 3700.0630
# Epoch 28: val_loss improved from 5263.16113 to 5153.77246, saving model to Weights-028--5153.77246.hdf5
# 4/4 [==============================] - 0s 33ms/step - loss: 2713.3979 - mean_absolute_error: 2713.3979 - val_loss: 5153.7725 - val_mean_absolute_error: 5153.7725
# Epoch 29/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2326.8057 - mean_absolute_error: 2326.8057
# Epoch 29: val_loss improved from 5153.77246 to 5141.64111, saving model to Weights-029--5141.64111.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 2526.4602 - mean_absolute_error: 2526.4602 - val_loss: 5141.6411 - val_mean_absolute_error: 5141.6411
# Epoch 30/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1936.2742 - mean_absolute_error: 1936.2742
# Epoch 30: val_loss improved from 5141.64111 to 5014.80518, saving model to Weights-030--5014.80518.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 2388.9424 - mean_absolute_error: 2388.9424 - val_loss: 5014.8052 - val_mean_absolute_error: 5014.8052
# Epoch 31/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1936.7998 - mean_absolute_error: 1936.7998
# Epoch 31: val_loss improved from 5014.80518 to 4811.74609, saving model to Weights-031--4811.74609.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 2243.8625 - mean_absolute_error: 2243.8625 - val_loss: 4811.7461 - val_mean_absolute_error: 4811.7461
# Epoch 32/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1853.8768 - mean_absolute_error: 1853.8768
# Epoch 32: val_loss improved from 4811.74609 to 4723.33447, saving model to Weights-032--4723.33447.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 2144.2437 - mean_absolute_error: 2144.2437 - val_loss: 4723.3345 - val_mean_absolute_error: 4723.3345
# Epoch 33/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2359.5234 - mean_absolute_error: 2359.5234
# Epoch 33: val_loss improved from 4723.33447 to 4685.73828, saving model to Weights-033--4685.73828.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 2035.2263 - mean_absolute_error: 2035.2263 - val_loss: 4685.7383 - val_mean_absolute_error: 4685.7383
# Epoch 34/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2019.6946 - mean_absolute_error: 2019.6946
# Epoch 34: val_loss improved from 4685.73828 to 4679.45703, saving model to Weights-034--4679.45703.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 1949.6626 - mean_absolute_error: 1949.6626 - val_loss: 4679.4570 - val_mean_absolute_error: 4679.4570
# Epoch 35/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1912.4482 - mean_absolute_error: 1912.4482
# Epoch 35: val_loss improved from 4679.45703 to 4601.34668, saving model to Weights-035--4601.34668.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 1884.8046 - mean_absolute_error: 1884.8046 - val_loss: 4601.3467 - val_mean_absolute_error: 4601.3467
# Epoch 36/500
# 1/4 [======>.......................] - ETA: 0s - loss: 2264.5527 - mean_absolute_error: 2264.5527
# Epoch 36: val_loss improved from 4601.34668 to 4464.68799, saving model to Weights-036--4464.68799.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 1793.1763 - mean_absolute_error: 1793.1763 - val_loss: 4464.6880 - val_mean_absolute_error: 4464.6880
# Epoch 37/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1343.0183 - mean_absolute_error: 1343.0183
# Epoch 37: val_loss improved from 4464.68799 to 4381.70801, saving model to Weights-037--4381.70801.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1734.5322 - mean_absolute_error: 1734.5322 - val_loss: 4381.7080 - val_mean_absolute_error: 4381.7080
# Epoch 38/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1205.7465 - mean_absolute_error: 1205.7465
# Epoch 38: val_loss improved from 4381.70801 to 4359.16748, saving model to Weights-038--4359.16748.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 1662.3024 - mean_absolute_error: 1662.3024 - val_loss: 4359.1675 - val_mean_absolute_error: 4359.1675
# Epoch 39/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1425.6853 - mean_absolute_error: 1425.6853
# Epoch 39: val_loss improved from 4359.16748 to 4280.90479, saving model to Weights-039--4280.90479.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1604.1172 - mean_absolute_error: 1604.1172 - val_loss: 4280.9048 - val_mean_absolute_error: 4280.9048
# Epoch 40/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1573.1931 - mean_absolute_error: 1573.1931
# Epoch 40: val_loss improved from 4280.90479 to 4149.38721, saving model to Weights-040--4149.38721.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1526.5458 - mean_absolute_error: 1526.5458 - val_loss: 4149.3872 - val_mean_absolute_error: 4149.3872
# Epoch 41/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1582.6545 - mean_absolute_error: 1582.6545
# Epoch 41: val_loss improved from 4149.38721 to 4058.63525, saving model to Weights-041--4058.63525.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1453.9042 - mean_absolute_error: 1453.9042 - val_loss: 4058.6353 - val_mean_absolute_error: 4058.6353
# Epoch 42/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1273.3877 - mean_absolute_error: 1273.3877
# Epoch 42: val_loss improved from 4058.63525 to 3977.42139, saving model to Weights-042--3977.42139.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 1403.8530 - mean_absolute_error: 1403.8530 - val_loss: 3977.4214 - val_mean_absolute_error: 3977.4214
# Epoch 43/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1057.8204 - mean_absolute_error: 1057.8204
# Epoch 43: val_loss improved from 3977.42139 to 3912.73950, saving model to Weights-043--3912.73950.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1350.0770 - mean_absolute_error: 1350.0770 - val_loss: 3912.7395 - val_mean_absolute_error: 3912.7395
# Epoch 44/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1755.9491 - mean_absolute_error: 1755.9491
# Epoch 44: val_loss improved from 3912.73950 to 3821.31470, saving model to Weights-044--3821.31470.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1297.5315 - mean_absolute_error: 1297.5315 - val_loss: 3821.3147 - val_mean_absolute_error: 3821.3147
# Epoch 45/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1103.4016 - mean_absolute_error: 1103.4016
# Epoch 45: val_loss improved from 3821.31470 to 3677.68311, saving model to Weights-045--3677.68311.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1247.1649 - mean_absolute_error: 1247.1649 - val_loss: 3677.6831 - val_mean_absolute_error: 3677.6831
# Epoch 46/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1448.7036 - mean_absolute_error: 1448.7036
# Epoch 46: val_loss improved from 3677.68311 to 3647.48926, saving model to Weights-046--3647.48926.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1190.1494 - mean_absolute_error: 1190.1494 - val_loss: 3647.4893 - val_mean_absolute_error: 3647.4893
# Epoch 47/500
# 1/4 [======>.......................] - ETA: 0s - loss: 863.3508 - mean_absolute_error: 863.3508
# Epoch 47: val_loss improved from 3647.48926 to 3556.54688, saving model to Weights-047--3556.54688.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1185.6732 - mean_absolute_error: 1185.6732 - val_loss: 3556.5469 - val_mean_absolute_error: 3556.5469
# Epoch 48/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1212.3374 - mean_absolute_error: 1212.3374
# Epoch 48: val_loss improved from 3556.54688 to 3390.84985, saving model to Weights-048--3390.84985.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 1118.1587 - mean_absolute_error: 1118.1587 - val_loss: 3390.8499 - val_mean_absolute_error: 3390.8499
# Epoch 49/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1077.1494 - mean_absolute_error: 1077.1494
# Epoch 49: val_loss improved from 3390.84985 to 3367.53052, saving model to Weights-049--3367.53052.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 1089.3170 - mean_absolute_error: 1089.3170 - val_loss: 3367.5305 - val_mean_absolute_error: 3367.5305
# Epoch 50/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1059.6162 - mean_absolute_error: 1059.6162
# Epoch 50: val_loss improved from 3367.53052 to 3343.16943, saving model to Weights-050--3343.16943.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 1044.9390 - mean_absolute_error: 1044.9390 - val_loss: 3343.1694 - val_mean_absolute_error: 3343.1694
# Epoch 51/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1112.2661 - mean_absolute_error: 1112.2661
# Epoch 51: val_loss improved from 3343.16943 to 3242.41919, saving model to Weights-051--3242.41919.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 1028.1857 - mean_absolute_error: 1028.1857 - val_loss: 3242.4192 - val_mean_absolute_error: 3242.4192
# Epoch 52/500
# 1/4 [======>.......................] - ETA: 0s - loss: 761.6282 - mean_absolute_error: 761.6282
# Epoch 52: val_loss improved from 3242.41919 to 3193.53711, saving model to Weights-052--3193.53711.hdf5
# 4/4 [==============================] - 0s 29ms/step - loss: 999.5099 - mean_absolute_error: 999.5099 - val_loss: 3193.5371 - val_mean_absolute_error: 3193.5371
# Epoch 53/500
# 1/4 [======>.......................] - ETA: 0s - loss: 927.7854 - mean_absolute_error: 927.7854
# Epoch 53: val_loss improved from 3193.53711 to 3168.73120, saving model to Weights-053--3168.73120.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 974.5770 - mean_absolute_error: 974.5770 - val_loss: 3168.7312 - val_mean_absolute_error: 3168.7312
# Epoch 54/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1165.2686 - mean_absolute_error: 1165.2686
# Epoch 54: val_loss improved from 3168.73120 to 3147.53589, saving model to Weights-054--3147.53589.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 957.7958 - mean_absolute_error: 957.7958 - val_loss: 3147.5359 - val_mean_absolute_error: 3147.5359
# Epoch 55/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1264.2087 - mean_absolute_error: 1264.2087
# Epoch 55: val_loss improved from 3147.53589 to 3056.73071, saving model to Weights-055--3056.73071.hdf5
# 4/4 [==============================] - 0s 26ms/step - loss: 939.2702 - mean_absolute_error: 939.2702 - val_loss: 3056.7307 - val_mean_absolute_error: 3056.7307
# Epoch 56/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1037.7107 - mean_absolute_error: 1037.7107
# Epoch 56: val_loss did not improve from 3056.73071
# 4/4 [==============================] - 0s 17ms/step - loss: 934.7986 - mean_absolute_error: 934.7986 - val_loss: 3081.7559 - val_mean_absolute_error: 3081.7559
# Epoch 57/500
# 1/4 [======>.......................] - ETA: 0s - loss: 763.1631 - mean_absolute_error: 763.1631
# Epoch 57: val_loss improved from 3056.73071 to 2986.82837, saving model to Weights-057--2986.82837.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 898.1545 - mean_absolute_error: 898.1545 - val_loss: 2986.8284 - val_mean_absolute_error: 2986.8284
# Epoch 58/500
# 1/4 [======>.......................] - ETA: 0s - loss: 720.7742 - mean_absolute_error: 720.7742
# Epoch 58: val_loss improved from 2986.82837 to 2978.24365, saving model to Weights-058--2978.24365.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 891.3579 - mean_absolute_error: 891.3579 - val_loss: 2978.2437 - val_mean_absolute_error: 2978.2437
# Epoch 59/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1013.4091 - mean_absolute_error: 1013.4091
# Epoch 59: val_loss improved from 2978.24365 to 2902.79272, saving model to Weights-059--2902.79272.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 866.3976 - mean_absolute_error: 866.3976 - val_loss: 2902.7927 - val_mean_absolute_error: 2902.7927
# Epoch 60/500
# 1/4 [======>.......................] - ETA: 0s - loss: 970.7045 - mean_absolute_error: 970.7045
# Epoch 60: val_loss improved from 2902.79272 to 2888.46265, saving model to Weights-060--2888.46265.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 850.4472 - mean_absolute_error: 850.4472 - val_loss: 2888.4626 - val_mean_absolute_error: 2888.4626
# Epoch 61/500
# 1/4 [======>.......................] - ETA: 0s - loss: 850.7047 - mean_absolute_error: 850.7047
# Epoch 61: val_loss improved from 2888.46265 to 2805.96924, saving model to Weights-061--2805.96924.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 833.0631 - mean_absolute_error: 833.0631 - val_loss: 2805.9692 - val_mean_absolute_error: 2805.9692
# Epoch 62/500
# 1/4 [======>.......................] - ETA: 0s - loss: 543.6519 - mean_absolute_error: 543.6519
# Epoch 62: val_loss improved from 2805.96924 to 2785.21655, saving model to Weights-062--2785.21655.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 825.6912 - mean_absolute_error: 825.6912 - val_loss: 2785.2166 - val_mean_absolute_error: 2785.2166
# Epoch 63/500
# 1/4 [======>.......................] - ETA: 0s - loss: 632.8058 - mean_absolute_error: 632.8058
# Epoch 63: val_loss improved from 2785.21655 to 2779.33569, saving model to Weights-063--2779.33569.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 793.0770 - mean_absolute_error: 793.0770 - val_loss: 2779.3357 - val_mean_absolute_error: 2779.3357
# Epoch 64/500
# 1/4 [======>.......................] - ETA: 0s - loss: 459.3729 - mean_absolute_error: 459.3729
# Epoch 64: val_loss improved from 2779.33569 to 2750.70020, saving model to Weights-064--2750.70020.hdf5
# 4/4 [==============================] - 0s 29ms/step - loss: 775.3865 - mean_absolute_error: 775.3865 - val_loss: 2750.7002 - val_mean_absolute_error: 2750.7002
# Epoch 65/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1044.3042 - mean_absolute_error: 1044.3042
# Epoch 65: val_loss improved from 2750.70020 to 2738.97681, saving model to Weights-065--2738.97681.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 768.5696 - mean_absolute_error: 768.5696 - val_loss: 2738.9768 - val_mean_absolute_error: 2738.9768
# Epoch 66/500
# 1/4 [======>.......................] - ETA: 0s - loss: 666.2748 - mean_absolute_error: 666.2748
# Epoch 66: val_loss did not improve from 2738.97681
# 4/4 [==============================] - 0s 15ms/step - loss: 750.6856 - mean_absolute_error: 750.6856 - val_loss: 2755.8950 - val_mean_absolute_error: 2755.8950
# Epoch 67/500
# 1/4 [======>.......................] - ETA: 0s - loss: 679.1919 - mean_absolute_error: 679.1919
# Epoch 67: val_loss improved from 2738.97681 to 2731.58667, saving model to Weights-067--2731.58667.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 740.9345 - mean_absolute_error: 740.9345 - val_loss: 2731.5867 - val_mean_absolute_error: 2731.5867
# Epoch 68/500
# 1/4 [======>.......................] - ETA: 0s - loss: 617.5140 - mean_absolute_error: 617.5140
# Epoch 68: val_loss did not improve from 2731.58667
# 4/4 [==============================] - 0s 14ms/step - loss: 741.8152 - mean_absolute_error: 741.8152 - val_loss: 2750.1060 - val_mean_absolute_error: 2750.1060
# Epoch 69/500
# 1/4 [======>.......................] - ETA: 0s - loss: 883.6619 - mean_absolute_error: 883.6619
# Epoch 69: val_loss did not improve from 2731.58667
# 4/4 [==============================] - 0s 14ms/step - loss: 739.3257 - mean_absolute_error: 739.3257 - val_loss: 2732.4380 - val_mean_absolute_error: 2732.4380
# Epoch 70/500
# 1/4 [======>.......................] - ETA: 0s - loss: 689.5562 - mean_absolute_error: 689.5562
# Epoch 70: val_loss improved from 2731.58667 to 2707.90796, saving model to Weights-070--2707.90796.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 718.2538 - mean_absolute_error: 718.2538 - val_loss: 2707.9080 - val_mean_absolute_error: 2707.9080
# Epoch 71/500
# 1/4 [======>.......................] - ETA: 0s - loss: 353.2499 - mean_absolute_error: 353.2499
# Epoch 71: val_loss improved from 2707.90796 to 2707.62012, saving model to Weights-071--2707.62012.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 703.9575 - mean_absolute_error: 703.9575 - val_loss: 2707.6201 - val_mean_absolute_error: 2707.6201
# Epoch 72/500
# 1/4 [======>.......................] - ETA: 0s - loss: 397.7381 - mean_absolute_error: 397.7381
# Epoch 72: val_loss improved from 2707.62012 to 2689.22314, saving model to Weights-072--2689.22314.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 705.4630 - mean_absolute_error: 705.4630 - val_loss: 2689.2231 - val_mean_absolute_error: 2689.2231
# Epoch 73/500
# 1/4 [======>.......................] - ETA: 0s - loss: 425.5228 - mean_absolute_error: 425.5228
# Epoch 73: val_loss improved from 2689.22314 to 2678.81543, saving model to Weights-073--2678.81543.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 687.0351 - mean_absolute_error: 687.0351 - val_loss: 2678.8154 - val_mean_absolute_error: 2678.8154
# Epoch 74/500
# 1/4 [======>.......................] - ETA: 0s - loss: 623.8268 - mean_absolute_error: 623.8268
# Epoch 74: val_loss improved from 2678.81543 to 2667.77368, saving model to Weights-074--2667.77368.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 683.8329 - mean_absolute_error: 683.8329 - val_loss: 2667.7737 - val_mean_absolute_error: 2667.7737
# Epoch 75/500
# 1/4 [======>.......................] - ETA: 0s - loss: 723.3971 - mean_absolute_error: 723.3971
# Epoch 75: val_loss did not improve from 2667.77368
# 4/4 [==============================] - 0s 17ms/step - loss: 664.0971 - mean_absolute_error: 664.0971 - val_loss: 2668.9917 - val_mean_absolute_error: 2668.9917
# Epoch 76/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1085.1533 - mean_absolute_error: 1085.1533
# Epoch 76: val_loss did not improve from 2667.77368
# 4/4 [==============================] - 0s 16ms/step - loss: 663.3284 - mean_absolute_error: 663.3284 - val_loss: 2675.9014 - val_mean_absolute_error: 2675.9014
# Epoch 77/500
# 1/4 [======>.......................] - ETA: 0s - loss: 663.1652 - mean_absolute_error: 663.1652
# Epoch 77: val_loss did not improve from 2667.77368
# 4/4 [==============================] - 0s 18ms/step - loss: 657.5139 - mean_absolute_error: 657.5139 - val_loss: 2688.5269 - val_mean_absolute_error: 2688.5269
# Epoch 78/500
# 1/4 [======>.......................] - ETA: 0s - loss: 652.5873 - mean_absolute_error: 652.5873
# Epoch 78: val_loss improved from 2667.77368 to 2661.11987, saving model to Weights-078--2661.11987.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 664.8901 - mean_absolute_error: 664.8901 - val_loss: 2661.1199 - val_mean_absolute_error: 2661.1199
# Epoch 79/500
# 1/4 [======>.......................] - ETA: 0s - loss: 902.2729 - mean_absolute_error: 902.2729
# Epoch 79: val_loss improved from 2661.11987 to 2659.67139, saving model to Weights-079--2659.67139.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 651.6182 - mean_absolute_error: 651.6182 - val_loss: 2659.6714 - val_mean_absolute_error: 2659.6714
# Epoch 80/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1076.8718 - mean_absolute_error: 1076.8718
# Epoch 80: val_loss improved from 2659.67139 to 2655.87769, saving model to Weights-080--2655.87769.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 640.5725 - mean_absolute_error: 640.5725 - val_loss: 2655.8777 - val_mean_absolute_error: 2655.8777
# Epoch 81/500
# 1/4 [======>.......................] - ETA: 0s - loss: 557.1912 - mean_absolute_error: 557.1912
# Epoch 81: val_loss did not improve from 2655.87769
# 4/4 [==============================] - 0s 14ms/step - loss: 624.7438 - mean_absolute_error: 624.7438 - val_loss: 2658.8999 - val_mean_absolute_error: 2658.8999
# Epoch 82/500
# 1/4 [======>.......................] - ETA: 0s - loss: 726.8922 - mean_absolute_error: 726.8922
# Epoch 82: val_loss improved from 2655.87769 to 2621.85083, saving model to Weights-082--2621.85083.hdf5
# 4/4 [==============================] - 0s 22ms/step - loss: 609.1005 - mean_absolute_error: 609.1005 - val_loss: 2621.8508 - val_mean_absolute_error: 2621.8508
# Epoch 83/500
# 1/4 [======>.......................] - ETA: 0s - loss: 425.5056 - mean_absolute_error: 425.5056
# Epoch 83: val_loss did not improve from 2621.85083
# 4/4 [==============================] - 0s 15ms/step - loss: 629.7456 - mean_absolute_error: 629.7456 - val_loss: 2652.1892 - val_mean_absolute_error: 2652.1892
# Epoch 84/500
# 1/4 [======>.......................] - ETA: 0s - loss: 1010.1266 - mean_absolute_error: 1010.1266
# Epoch 84: val_loss improved from 2621.85083 to 2608.23462, saving model to Weights-084--2608.23462.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 620.4576 - mean_absolute_error: 620.4576 - val_loss: 2608.2346 - val_mean_absolute_error: 2608.2346
# Epoch 85/500
# 1/4 [======>.......................] - ETA: 0s - loss: 603.6819 - mean_absolute_error: 603.6819
# Epoch 85: val_loss did not improve from 2608.23462
# 4/4 [==============================] - 0s 16ms/step - loss: 628.7058 - mean_absolute_error: 628.7058 - val_loss: 2629.8411 - val_mean_absolute_error: 2629.8411
# Epoch 86/500
# 1/4 [======>.......................] - ETA: 0s - loss: 666.7338 - mean_absolute_error: 666.7338
# Epoch 86: val_loss improved from 2608.23462 to 2581.58691, saving model to Weights-086--2581.58691.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 612.4957 - mean_absolute_error: 612.4957 - val_loss: 2581.5869 - val_mean_absolute_error: 2581.5869
# Epoch 87/500
# 1/4 [======>.......................] - ETA: 0s - loss: 498.8089 - mean_absolute_error: 498.8089
# Epoch 87: val_loss did not improve from 2581.58691
# 4/4 [==============================] - 0s 13ms/step - loss: 625.8121 - mean_absolute_error: 625.8121 - val_loss: 2615.6902 - val_mean_absolute_error: 2615.6902
# Epoch 88/500
# 1/4 [======>.......................] - ETA: 0s - loss: 671.2109 - mean_absolute_error: 671.2109
# Epoch 88: val_loss did not improve from 2581.58691
# 4/4 [==============================] - 0s 14ms/step - loss: 600.4440 - mean_absolute_error: 600.4440 - val_loss: 2625.8188 - val_mean_absolute_error: 2625.8188
# Epoch 89/500
# 1/4 [======>.......................] - ETA: 0s - loss: 729.8135 - mean_absolute_error: 729.8135
# Epoch 89: val_loss did not improve from 2581.58691
# 4/4 [==============================] - 0s 28ms/step - loss: 611.9256 - mean_absolute_error: 611.9256 - val_loss: 2623.2412 - val_mean_absolute_error: 2623.2412
# Epoch 90/500
# 1/4 [======>.......................] - ETA: 0s - loss: 464.5970 - mean_absolute_error: 464.5970
# Epoch 90: val_loss did not improve from 2581.58691
# 4/4 [==============================] - 0s 17ms/step - loss: 597.6524 - mean_absolute_error: 597.6524 - val_loss: 2595.2263 - val_mean_absolute_error: 2595.2263
# Epoch 91/500
# 1/4 [======>.......................] - ETA: 0s - loss: 828.6591 - mean_absolute_error: 828.6591
# Epoch 91: val_loss improved from 2581.58691 to 2564.56470, saving model to Weights-091--2564.56470.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 598.5264 - mean_absolute_error: 598.5264 - val_loss: 2564.5647 - val_mean_absolute_error: 2564.5647
# Epoch 92/500
# 1/4 [======>.......................] - ETA: 0s - loss: 552.4956 - mean_absolute_error: 552.4956
# Epoch 92: val_loss did not improve from 2564.56470
# 4/4 [==============================] - 0s 17ms/step - loss: 583.9794 - mean_absolute_error: 583.9794 - val_loss: 2588.8384 - val_mean_absolute_error: 2588.8384
# Epoch 93/500
# 1/4 [======>.......................] - ETA: 0s - loss: 740.4781 - mean_absolute_error: 740.4781
# Epoch 93: val_loss improved from 2564.56470 to 2548.21069, saving model to Weights-093--2548.21069.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 578.1512 - mean_absolute_error: 578.1512 - val_loss: 2548.2107 - val_mean_absolute_error: 2548.2107
# Epoch 94/500
# 1/4 [======>.......................] - ETA: 0s - loss: 507.1939 - mean_absolute_error: 507.1939
# Epoch 94: val_loss did not improve from 2548.21069
# 4/4 [==============================] - 0s 15ms/step - loss: 562.9291 - mean_absolute_error: 562.9291 - val_loss: 2564.0369 - val_mean_absolute_error: 2564.0369
# Epoch 95/500
# 1/4 [======>.......................] - ETA: 0s - loss: 354.6172 - mean_absolute_error: 354.6172
# Epoch 95: val_loss did not improve from 2548.21069
# 4/4 [==============================] - 0s 14ms/step - loss: 552.0652 - mean_absolute_error: 552.0652 - val_loss: 2556.6655 - val_mean_absolute_error: 2556.6655
# Epoch 96/500
# 1/4 [======>.......................] - ETA: 0s - loss: 852.6594 - mean_absolute_error: 852.6594
# Epoch 96: val_loss did not improve from 2548.21069
# 4/4 [==============================] - 0s 15ms/step - loss: 549.4301 - mean_absolute_error: 549.4301 - val_loss: 2602.3462 - val_mean_absolute_error: 2602.3462
# Epoch 97/500
# 1/4 [======>.......................] - ETA: 0s - loss: 530.1965 - mean_absolute_error: 530.1965
# Epoch 97: val_loss did not improve from 2548.21069
# 4/4 [==============================] - 0s 16ms/step - loss: 569.1465 - mean_absolute_error: 569.1465 - val_loss: 2587.9160 - val_mean_absolute_error: 2587.9160
# Epoch 98/500
# 1/4 [======>.......................] - ETA: 0s - loss: 375.8882 - mean_absolute_error: 375.8882
# Epoch 98: val_loss did not improve from 2548.21069
# 4/4 [==============================] - 0s 17ms/step - loss: 553.3831 - mean_absolute_error: 553.3831 - val_loss: 2604.6638 - val_mean_absolute_error: 2604.6638
# Epoch 99/500
# 1/4 [======>.......................] - ETA: 0s - loss: 486.7839 - mean_absolute_error: 486.7839
# Epoch 99: val_loss improved from 2548.21069 to 2535.60498, saving model to Weights-099--2535.60498.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 600.5559 - mean_absolute_error: 600.5559 - val_loss: 2535.6050 - val_mean_absolute_error: 2535.6050
# Epoch 100/500
# 1/4 [======>.......................] - ETA: 0s - loss: 775.5968 - mean_absolute_error: 775.5968
# Epoch 100: val_loss did not improve from 2535.60498
# 4/4 [==============================] - 0s 16ms/step - loss: 559.1256 - mean_absolute_error: 559.1256 - val_loss: 2546.1536 - val_mean_absolute_error: 2546.1536
# Epoch 101/500
# 1/4 [======>.......................] - ETA: 0s - loss: 863.8511 - mean_absolute_error: 863.8511
# Epoch 101: val_loss improved from 2535.60498 to 2523.38110, saving model to Weights-101--2523.38110.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 565.0514 - mean_absolute_error: 565.0514 - val_loss: 2523.3811 - val_mean_absolute_error: 2523.3811
# Epoch 102/500
# 1/4 [======>.......................] - ETA: 0s - loss: 390.2018 - mean_absolute_error: 390.2018
# Epoch 102: val_loss did not improve from 2523.38110
# 4/4 [==============================] - 0s 16ms/step - loss: 556.8347 - mean_absolute_error: 556.8347 - val_loss: 2537.9534 - val_mean_absolute_error: 2537.9534
# Epoch 103/500
# 1/4 [======>.......................] - ETA: 0s - loss: 319.7254 - mean_absolute_error: 319.7254
# Epoch 103: val_loss did not improve from 2523.38110
# 4/4 [==============================] - 0s 16ms/step - loss: 534.9885 - mean_absolute_error: 534.9885 - val_loss: 2553.9583 - val_mean_absolute_error: 2553.9583
# Epoch 104/500
# 1/4 [======>.......................] - ETA: 0s - loss: 384.4398 - mean_absolute_error: 384.4398
# Epoch 104: val_loss improved from 2523.38110 to 2515.34863, saving model to Weights-104--2515.34863.hdf5
# 4/4 [==============================] - 0s 24ms/step - loss: 522.7356 - mean_absolute_error: 522.7356 - val_loss: 2515.3486 - val_mean_absolute_error: 2515.3486
# Epoch 105/500
# 1/4 [======>.......................] - ETA: 0s - loss: 780.6217 - mean_absolute_error: 780.6217
# Epoch 105: val_loss did not improve from 2515.34863
# 4/4 [==============================] - 0s 19ms/step - loss: 520.4045 - mean_absolute_error: 520.4045 - val_loss: 2539.6860 - val_mean_absolute_error: 2539.6860
# Epoch 106/500
# 1/4 [======>.......................] - ETA: 0s - loss: 866.3940 - mean_absolute_error: 866.3940
# Epoch 106: val_loss improved from 2515.34863 to 2511.78027, saving model to Weights-106--2511.78027.hdf5
# 4/4 [==============================] - 0s 23ms/step - loss: 545.5190 - mean_absolute_error: 545.5190 - val_loss: 2511.7803 - val_mean_absolute_error: 2511.7803
# Epoch 107/500
# 1/4 [======>.......................] - ETA: 0s - loss: 380.2397 - mean_absolute_error: 380.2397
# Epoch 107: val_loss did not improve from 2511.78027
# 4/4 [==============================] - 0s 17ms/step - loss: 529.3045 - mean_absolute_error: 529.3045 - val_loss: 2528.9209 - val_mean_absolute_error: 2528.9209
# Epoch 108/500
# 1/4 [======>.......................] - ETA: 0s - loss: 353.9779 - mean_absolute_error: 353.9779
# Epoch 108: val_loss did not improve from 2511.78027
# 4/4 [==============================] - 0s 15ms/step - loss: 537.4531 - mean_absolute_error: 537.4531 - val_loss: 2524.0571 - val_mean_absolute_error: 2524.0571
# Epoch 109/500
# 1/4 [======>.......................] - ETA: 0s - loss: 433.5620 - mean_absolute_error: 433.5620
# Epoch 109: val_loss did not improve from 2511.78027
# 4/4 [==============================] - 0s 16ms/step - loss: 506.9868 - mean_absolute_error: 506.9868 - val_loss: 2533.3374 - val_mean_absolute_error: 2533.3374
# Epoch 110/500
# 1/4 [======>.......................] - ETA: 0s - loss: 435.8823 - mean_absolute_error: 435.8823
# Epoch 110: val_loss did not improve from 2511.78027
# 4/4 [==============================] - 0s 16ms/step - loss: 536.0308 - mean_absolute_error: 536.0308 - val_loss: 2515.7549 - val_mean_absolute_error: 2515.7549
# Epoch 111/500
# 1/4 [======>.......................] - ETA: 0s - loss: 669.2211 - mean_absolute_error: 669.2211
# Epoch 111: val_loss improved from 2511.78027 to 2507.43213, saving model to Weights-111--2507.43213.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 505.6896 - mean_absolute_error: 505.6896 - val_loss: 2507.4321 - val_mean_absolute_error: 2507.4321
# Epoch 112/500
# 1/4 [======>.......................] - ETA: 0s - loss: 526.7077 - mean_absolute_error: 526.7077
# Epoch 112: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 13ms/step - loss: 503.1069 - mean_absolute_error: 503.1069 - val_loss: 2540.0818 - val_mean_absolute_error: 2540.0818
# Epoch 113/500
# 1/4 [======>.......................] - ETA: 0s - loss: 566.0107 - mean_absolute_error: 566.0107
# Epoch 113: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 18ms/step - loss: 514.3592 - mean_absolute_error: 514.3592 - val_loss: 2531.2312 - val_mean_absolute_error: 2531.2312
# Epoch 114/500
# 1/4 [======>.......................] - ETA: 0s - loss: 625.4360 - mean_absolute_error: 625.4360
# Epoch 114: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 15ms/step - loss: 501.9646 - mean_absolute_error: 501.9646 - val_loss: 2566.4634 - val_mean_absolute_error: 2566.4634
# Epoch 115/500
# 1/4 [======>.......................] - ETA: 0s - loss: 399.8195 - mean_absolute_error: 399.8195
# Epoch 115: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 14ms/step - loss: 542.0274 - mean_absolute_error: 542.0274 - val_loss: 2541.5291 - val_mean_absolute_error: 2541.5291
# Epoch 116/500
# 1/4 [======>.......................] - ETA: 0s - loss: 297.4976 - mean_absolute_error: 297.4976
# Epoch 116: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 14ms/step - loss: 519.8092 - mean_absolute_error: 519.8092 - val_loss: 2548.0000 - val_mean_absolute_error: 2548.0000
# Epoch 117/500
# 1/4 [======>.......................] - ETA: 0s - loss: 715.3605 - mean_absolute_error: 715.3605
# Epoch 117: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 14ms/step - loss: 502.1767 - mean_absolute_error: 502.1767 - val_loss: 2529.4209 - val_mean_absolute_error: 2529.4209
# Epoch 118/500
# 1/4 [======>.......................] - ETA: 0s - loss: 789.4136 - mean_absolute_error: 789.4136
# Epoch 118: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 16ms/step - loss: 491.0744 - mean_absolute_error: 491.0744 - val_loss: 2512.7395 - val_mean_absolute_error: 2512.7395
# Epoch 119/500
# 1/4 [======>.......................] - ETA: 0s - loss: 308.9960 - mean_absolute_error: 308.9960
# Epoch 119: val_loss did not improve from 2507.43213
# 4/4 [==============================] - 0s 15ms/step - loss: 492.0597 - mean_absolute_error: 492.0597 - val_loss: 2518.4124 - val_mean_absolute_error: 2518.4124
# Epoch 120/500
# 1/4 [======>.......................] - ETA: 0s - loss: 330.0640 - mean_absolute_error: 330.0640
# Epoch 120: val_loss improved from 2507.43213 to 2505.28491, saving model to Weights-120--2505.28491.hdf5
# 4/4 [==============================] - 0s 25ms/step - loss: 504.3747 - mean_absolute_error: 504.3747 - val_loss: 2505.2849 - val_mean_absolute_error: 2505.2849
# Epoch 121/500
# 1/4 [======>.......................] - ETA: 0s - loss: 241.2615 - mean_absolute_error: 241.2615
# Epoch 121: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 18ms/step - loss: 505.8083 - mean_absolute_error: 505.8083 - val_loss: 2536.5420 - val_mean_absolute_error: 2536.5420
# Epoch 122/500
# 1/4 [======>.......................] - ETA: 0s - loss: 400.4904 - mean_absolute_error: 400.4904
# Epoch 122: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 17ms/step - loss: 512.2195 - mean_absolute_error: 512.2195 - val_loss: 2505.3264 - val_mean_absolute_error: 2505.3264
# Epoch 123/500
# 1/4 [======>.......................] - ETA: 0s - loss: 508.5349 - mean_absolute_error: 508.5349
# Epoch 123: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 504.2735 - mean_absolute_error: 504.2735 - val_loss: 2540.8022 - val_mean_absolute_error: 2540.8022
# Epoch 124/500
# 1/4 [======>.......................] - ETA: 0s - loss: 707.9616 - mean_absolute_error: 707.9616
# Epoch 124: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 15ms/step - loss: 502.9643 - mean_absolute_error: 502.9643 - val_loss: 2531.1294 - val_mean_absolute_error: 2531.1294
# Epoch 125/500
# 1/4 [======>.......................] - ETA: 0s - loss: 433.1382 - mean_absolute_error: 433.1382
# Epoch 125: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 502.3392 - mean_absolute_error: 502.3392 - val_loss: 2545.7649 - val_mean_absolute_error: 2545.7649
# Epoch 126/500
# 1/4 [======>.......................] - ETA: 0s - loss: 829.2128 - mean_absolute_error: 829.2128
# Epoch 126: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 15ms/step - loss: 517.3805 - mean_absolute_error: 517.3805 - val_loss: 2514.1392 - val_mean_absolute_error: 2514.1392
# Epoch 127/500
# 1/4 [======>.......................] - ETA: 0s - loss: 286.5219 - mean_absolute_error: 286.5219
# Epoch 127: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 14ms/step - loss: 503.6477 - mean_absolute_error: 503.6477 - val_loss: 2520.4688 - val_mean_absolute_error: 2520.4688
# Epoch 128/500
# 1/4 [======>.......................] - ETA: 0s - loss: 363.3975 - mean_absolute_error: 363.3975
# Epoch 128: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 510.1460 - mean_absolute_error: 510.1460 - val_loss: 2537.0850 - val_mean_absolute_error: 2537.0850
# Epoch 129/500
# 1/4 [======>.......................] - ETA: 0s - loss: 358.2557 - mean_absolute_error: 358.2557
# Epoch 129: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 486.9814 - mean_absolute_error: 486.9814 - val_loss: 2529.3157 - val_mean_absolute_error: 2529.3157
# Epoch 130/500
# 1/4 [======>.......................] - ETA: 0s - loss: 371.2654 - mean_absolute_error: 371.2654
# Epoch 130: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 17ms/step - loss: 480.3797 - mean_absolute_error: 480.3797 - val_loss: 2527.9614 - val_mean_absolute_error: 2527.9614
# Epoch 131/500
# 1/4 [======>.......................] - ETA: 0s - loss: 478.5863 - mean_absolute_error: 478.5863
# Epoch 131: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 464.4048 - mean_absolute_error: 464.4048 - val_loss: 2512.5879 - val_mean_absolute_error: 2512.5879
# Epoch 132/500
# 1/4 [======>.......................] - ETA: 0s - loss: 631.8021 - mean_absolute_error: 631.8021
# Epoch 132: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 16ms/step - loss: 468.2838 - mean_absolute_error: 468.2838 - val_loss: 2509.2158 - val_mean_absolute_error: 2509.2158
# Epoch 133/500
# 1/4 [======>.......................] - ETA: 0s - loss: 756.5330 - mean_absolute_error: 756.5330
# Epoch 133: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 18ms/step - loss: 455.5410 - mean_absolute_error: 455.5410 - val_loss: 2513.5178 - val_mean_absolute_error: 2513.5178
# Epoch 134/500
# 1/4 [======>.......................] - ETA: 0s - loss: 315.7439 - mean_absolute_error: 315.7439
# Epoch 134: val_loss did not improve from 2505.28491
# 4/4 [==============================] - 0s 15ms/step - loss: 459.0701 - mean_absolute_error: 459.0701 - val_loss: 2534.2107 - val_mean_absolute_error: 2534.2107
# Epoch 135/500
# 1/4 [======>.......................] - ETA: 0s - loss: 764.7905 - mean_absolute_error: 764.7905
# Epoch 135: val_loss did not improve from 2505.28491
# ...
# Epoch 453/500
# 1/4 [======>.......................] - ETA: 0s - loss: 247.0807 - mean_absolute_error: 247.0807
# Epoch 453: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 20ms/step - loss: 273.9986 - mean_absolute_error: 273.9986 - val_loss: 2145.4077 - val_mean_absolute_error: 2145.4077
# Epoch 454/500
# 1/4 [======>.......................] - ETA: 0s - loss: 378.8243 - mean_absolute_error: 378.8243
# Epoch 454: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 19ms/step - loss: 272.1361 - mean_absolute_error: 272.1361 - val_loss: 2139.9717 - val_mean_absolute_error: 2139.9717
# Epoch 455/500
# 1/4 [======>.......................] - ETA: 0s - loss: 230.7628 - mean_absolute_error: 230.7628
# Epoch 455: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 18ms/step - loss: 265.8005 - mean_absolute_error: 265.8005 - val_loss: 2145.6587 - val_mean_absolute_error: 2145.6587
# Epoch 456/500
# 1/4 [======>.......................] - ETA: 0s - loss: 155.4784 - mean_absolute_error: 155.4784
# Epoch 456: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 21ms/step - loss: 263.7186 - mean_absolute_error: 263.7186 - val_loss: 2150.2051 - val_mean_absolute_error: 2150.2051
# Epoch 457/500
# 1/4 [======>.......................] - ETA: 0s - loss: 376.6534 - mean_absolute_error: 376.6534
# Epoch 457: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 22ms/step - loss: 257.8481 - mean_absolute_error: 257.8481 - val_loss: 2130.8044 - val_mean_absolute_error: 2130.8044
# Epoch 458/500
# 1/4 [======>.......................] - ETA: 0s - loss: 329.2826 - mean_absolute_error: 329.2826
# Epoch 458: val_loss did not improve from 2119.34155
# 4/4 [==============================] - 0s 20ms/step - loss: 270.7371 - mean_absolute_error: 270.7371 - val_loss: 2120.5371 - val_mean_absolute_error: 2120.5371
# Epoch 459/500
# 1/4 [======>.......................] - ETA: 0s - loss: 367.4179 - mean_absolute_error: 367.4179
# Epoch 459: val_loss improved from 2119.34155 to 2115.27588, saving model to Weights-459--2115.27588.hdf5
# 4/4 [==============================] - 0s 33ms/step - loss: 281.3652 - mean_absolute_error: 281.3652 - val_loss: 2115.2759 - val_mean_absolute_error: 2115.2759
# Epoch 460/500
# 1/4 [======>.......................] - ETA: 0s - loss: 172.3410 - mean_absolute_error: 172.3410
# Epoch 460: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 17ms/step - loss: 273.1897 - mean_absolute_error: 273.1897 - val_loss: 2121.0750 - val_mean_absolute_error: 2121.0750
# Epoch 461/500
# 1/4 [======>.......................] - ETA: 0s - loss: 341.5291 - mean_absolute_error: 341.5291
# Epoch 461: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 19ms/step - loss: 261.2937 - mean_absolute_error: 261.2937 - val_loss: 2123.0476 - val_mean_absolute_error: 2123.0476
# Epoch 462/500
# 1/4 [======>.......................] - ETA: 0s - loss: 302.0305 - mean_absolute_error: 302.0305
# Epoch 462: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 20ms/step - loss: 264.5356 - mean_absolute_error: 264.5356 - val_loss: 2125.8584 - val_mean_absolute_error: 2125.8584
# Epoch 463/500
# 1/4 [======>.......................] - ETA: 0s - loss: 359.1097 - mean_absolute_error: 359.1097
# Epoch 463: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 24ms/step - loss: 255.5853 - mean_absolute_error: 255.5853 - val_loss: 2135.4556 - val_mean_absolute_error: 2135.4556
# Epoch 464/500
# 1/4 [======>.......................] - ETA: 0s - loss: 200.7982 - mean_absolute_error: 200.7982
# Epoch 464: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 18ms/step - loss: 263.9046 - mean_absolute_error: 263.9046 - val_loss: 2144.7139 - val_mean_absolute_error: 2144.7139
# Epoch 465/500
# 1/4 [======>.......................] - ETA: 0s - loss: 211.1685 - mean_absolute_error: 211.1685
# Epoch 465: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 21ms/step - loss: 263.3685 - mean_absolute_error: 263.3685 - val_loss: 2127.0132 - val_mean_absolute_error: 2127.0132
# Epoch 466/500
# 1/4 [======>.......................] - ETA: 0s - loss: 184.5616 - mean_absolute_error: 184.5616
# Epoch 466: val_loss did not improve from 2115.27588
# 4/4 [==============================] - 0s 18ms/step - loss: 272.3713 - mean_absolute_error: 272.3713 - val_loss: 2118.0889 - val_mean_absolute_error: 2118.0889
# Epoch 467/500
# 1/4 [======>.......................] - ETA: 0s - loss: 172.9845 - mean_absolute_error: 172.9845
# Epoch 467: val_loss improved from 2115.27588 to 2103.91675, saving model to Weights-467--2103.91675.hdf5
# 4/4 [==============================] - 0s 28ms/step - loss: 304.6688 - mean_absolute_error: 304.6688 - val_loss: 2103.9167 - val_mean_absolute_error: 2103.9167
# Epoch 468/500
# 1/4 [======>.......................] - ETA: 0s - loss: 278.9627 - mean_absolute_error: 278.9627
# Epoch 468: val_loss did not improve from 2103.91675
# 4/4 [==============================] - 0s 16ms/step - loss: 293.5302 - mean_absolute_error: 293.5302 - val_loss: 2106.9634 - val_mean_absolute_error: 2106.9634
# Epoch 469/500
# 1/4 [======>.......................] - ETA: 0s - loss: 137.6899 - mean_absolute_error: 137.6899
# Epoch 469: val_loss did not improve from 2103.91675
# 4/4 [==============================] - 0s 17ms/step - loss: 281.8892 - mean_absolute_error: 281.8892 - val_loss: 2112.2354 - val_mean_absolute_error: 2112.2354
# Epoch 470/500
# 1/4 [======>.......................] - ETA: 0s - loss: 172.3556 - mean_absolute_error: 172.3556
# Epoch 470: val_loss improved from 2103.91675 to 2103.88379, saving model to Weights-470--2103.88379.hdf5
# 4/4 [==============================] - 0s 30ms/step - loss: 275.1598 - mean_absolute_error: 275.1598 - val_loss: 2103.8838 - val_mean_absolute_error: 2103.8838
# Epoch 471/500
# 1/4 [======>.......................] - ETA: 0s - loss: 387.9609 - mean_absolute_error: 387.9609
# Epoch 471: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 22ms/step - loss: 291.6178 - mean_absolute_error: 291.6178 - val_loss: 2120.7080 - val_mean_absolute_error: 2120.7080
# Epoch 472/500
# 1/4 [======>.......................] - ETA: 0s - loss: 164.3958 - mean_absolute_error: 164.3958
# Epoch 472: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 22ms/step - loss: 286.5231 - mean_absolute_error: 286.5231 - val_loss: 2125.9902 - val_mean_absolute_error: 2125.9902
# Epoch 473/500
# 1/4 [======>.......................] - ETA: 0s - loss: 238.6453 - mean_absolute_error: 238.6453
# Epoch 473: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 21ms/step - loss: 284.2201 - mean_absolute_error: 284.2201 - val_loss: 2115.5193 - val_mean_absolute_error: 2115.5193
# Epoch 474/500
# 1/4 [======>.......................] - ETA: 0s - loss: 365.7239 - mean_absolute_error: 365.7239
# Epoch 474: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 22ms/step - loss: 280.2261 - mean_absolute_error: 280.2261 - val_loss: 2119.0305 - val_mean_absolute_error: 2119.0305
# Epoch 475/500
# 1/4 [======>.......................] - ETA: 0s - loss: 421.8264 - mean_absolute_error: 421.8264
# Epoch 475: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 19ms/step - loss: 306.0189 - mean_absolute_error: 306.0189 - val_loss: 2129.5112 - val_mean_absolute_error: 2129.5112
# Epoch 476/500
# 1/4 [======>.......................] - ETA: 0s - loss: 188.5218 - mean_absolute_error: 188.5218
# Epoch 476: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 23ms/step - loss: 296.7171 - mean_absolute_error: 296.7171 - val_loss: 2139.3323 - val_mean_absolute_error: 2139.3323
# Epoch 477/500
# 1/4 [======>.......................] - ETA: 0s - loss: 225.3835 - mean_absolute_error: 225.3835
# Epoch 477: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 19ms/step - loss: 289.8024 - mean_absolute_error: 289.8024 - val_loss: 2133.3032 - val_mean_absolute_error: 2133.3032
# Epoch 478/500
# 1/4 [======>.......................] - ETA: 0s - loss: 161.4346 - mean_absolute_error: 161.4346
# Epoch 478: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 20ms/step - loss: 304.6250 - mean_absolute_error: 304.6250 - val_loss: 2114.4658 - val_mean_absolute_error: 2114.4658
# Epoch 479/500
# 1/4 [======>.......................] - ETA: 0s - loss: 310.4661 - mean_absolute_error: 310.4661
# Epoch 479: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 23ms/step - loss: 292.1502 - mean_absolute_error: 292.1502 - val_loss: 2108.9963 - val_mean_absolute_error: 2108.9963
# Epoch 480/500
# 1/4 [======>.......................] - ETA: 0s - loss: 353.6447 - mean_absolute_error: 353.6447
# Epoch 480: val_loss did not improve from 2103.88379
# 4/4 [==============================] - 0s 19ms/step - loss: 270.2299 - mean_absolute_error: 270.2299 - val_loss: 2111.1824 - val_mean_absolute_error: 2111.1824
# Epoch 481/500
# 1/4 [======>.......................] - ETA: 0s - loss: 428.7933 - mean_absolute_error: 428.7933
# Epoch 481: val_loss improved from 2103.88379 to 2090.45166, saving model to Weights-481--2090.45166.hdf5
# 4/4 [==============================] - 0s 31ms/step - loss: 279.5220 - mean_absolute_error: 279.5220 - val_loss: 2090.4517 - val_mean_absolute_error: 2090.4517
# Epoch 482/500
# 1/4 [======>.......................] - ETA: 0s - loss: 374.1807 - mean_absolute_error: 374.1807
# Epoch 482: val_loss did not improve from 2090.45166
# 4/4 [==============================] - 0s 21ms/step - loss: 276.5075 - mean_absolute_error: 276.5075 - val_loss: 2095.0298 - val_mean_absolute_error: 2095.0298
# Epoch 483/500
# 1/4 [======>.......................] - ETA: 0s - loss: 338.2007 - mean_absolute_error: 338.2007
# Epoch 483: val_loss did not improve from 2090.45166
# 4/4 [==============================] - 0s 26ms/step - loss: 278.7679 - mean_absolute_error: 278.7679 - val_loss: 2111.8018 - val_mean_absolute_error: 2111.8018
# Epoch 484/500
# 1/4 [======>.......................] - ETA: 0s - loss: 110.9520 - mean_absolute_error: 110.9520
# Epoch 484: val_loss did not improve from 2090.45166
# 4/4 [==============================] - 0s 20ms/step - loss: 273.0879 - mean_absolute_error: 273.0879 - val_loss: 2106.8784 - val_mean_absolute_error: 2106.8784
# Epoch 485/500
# 1/4 [======>.......................] - ETA: 0s - loss: 247.7161 - mean_absolute_error: 247.7161
# Epoch 485: val_loss did not improve from 2090.45166
# 4/4 [==============================] - 0s 20ms/step - loss: 262.8640 - mean_absolute_error: 262.8640 - val_loss: 2092.3521 - val_mean_absolute_error: 2092.3521
# Epoch 486/500
# 1/4 [======>.......................] - ETA: 0s - loss: 256.3615 - mean_absolute_error: 256.3615
# Epoch 486: val_loss improved from 2090.45166 to 2090.12817, saving model to Weights-486--2090.12817.hdf5
# 4/4 [==============================] - 0s 31ms/step - loss: 276.3187 - mean_absolute_error: 276.3187 - val_loss: 2090.1282 - val_mean_absolute_error: 2090.1282
# Epoch 487/500
# 1/4 [======>.......................] - ETA: 0s - loss: 242.7352 - mean_absolute_error: 242.7352
# Epoch 487: val_loss did not improve from 2090.12817
# 4/4 [==============================] - 0s 17ms/step - loss: 268.2040 - mean_absolute_error: 268.2040 - val_loss: 2092.5215 - val_mean_absolute_error: 2092.5215
# Epoch 488/500
# 1/4 [======>.......................] - ETA: 0s - loss: 163.4754 - mean_absolute_error: 163.4754
# Epoch 488: val_loss improved from 2090.12817 to 2083.21851, saving model to Weights-488--2083.21851.hdf5
# 4/4 [==============================] - 0s 29ms/step - loss: 269.7644 - mean_absolute_error: 269.7644 - val_loss: 2083.2185 - val_mean_absolute_error: 2083.2185
# Epoch 489/500
# 1/4 [======>.......................] - ETA: 0s - loss: 401.3540 - mean_absolute_error: 401.3540
# Epoch 489: val_loss improved from 2083.21851 to 2072.50488, saving model to Weights-489--2072.50488.hdf5
# 4/4 [==============================] - 0s 27ms/step - loss: 261.9696 - mean_absolute_error: 261.9696 - val_loss: 2072.5049 - val_mean_absolute_error: 2072.5049
# Epoch 490/500
# 1/4 [======>.......................] - ETA: 0s - loss: 293.4587 - mean_absolute_error: 293.4587
# Epoch 490: val_loss did not improve from 2072.50488
# 4/4 [==============================] - 0s 25ms/step - loss: 264.2810 - mean_absolute_error: 264.2810 - val_loss: 2081.1023 - val_mean_absolute_error: 2081.1023
# Epoch 491/500
# 1/4 [======>.......................] - ETA: 0s - loss: 206.8696 - mean_absolute_error: 206.8696
# Epoch 491: val_loss did not improve from 2072.50488
# 4/4 [==============================] - 0s 18ms/step - loss: 251.4441 - mean_absolute_error: 251.4441 - val_loss: 2101.2471 - val_mean_absolute_error: 2101.2471
# Epoch 492/500
# 1/4 [======>.......................] - ETA: 0s - loss: 359.1241 - mean_absolute_error: 359.1241
# Epoch 492: val_loss did not improve from 2072.50488
# 4/4 [==============================] - 0s 18ms/step - loss: 251.7651 - mean_absolute_error: 251.7651 - val_loss: 2087.0459 - val_mean_absolute_error: 2087.0459
# Epoch 493/500
# 1/4 [======>.......................] - ETA: 0s - loss: 151.3289 - mean_absolute_error: 151.3289
# Epoch 493: val_loss did not improve from 2072.50488
# 4/4 [==============================] - 0s 20ms/step - loss: 258.7260 - mean_absolute_error: 258.7260 - val_loss: 2073.0063 - val_mean_absolute_error: 2073.0063
# Epoch 494/500
# 1/4 [======>.......................] - ETA: 0s - loss: 286.7232 - mean_absolute_error: 286.7232
# Epoch 494: val_loss improved from 2072.50488 to 2070.12134, saving model to Weights-494--2070.12134.hdf5
# 4/4 [==============================] - 0s 30ms/step - loss: 265.6144 - mean_absolute_error: 265.6144 - val_loss: 2070.1213 - val_mean_absolute_error: 2070.1213
# Epoch 495/500
# 1/4 [======>.......................] - ETA: 0s - loss: 275.0837 - mean_absolute_error: 275.0837
# Epoch 495: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 16ms/step - loss: 265.1929 - mean_absolute_error: 265.1929 - val_loss: 2088.2231 - val_mean_absolute_error: 2088.2231
# Epoch 496/500
# 1/4 [======>.......................] - ETA: 0s - loss: 253.5076 - mean_absolute_error: 253.5076
# Epoch 496: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 23ms/step - loss: 243.8403 - mean_absolute_error: 243.8403 - val_loss: 2085.6367 - val_mean_absolute_error: 2085.6367
# Epoch 497/500
# 1/4 [======>.......................] - ETA: 0s - loss: 208.0391 - mean_absolute_error: 208.0391
# Epoch 497: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 16ms/step - loss: 244.7563 - mean_absolute_error: 244.7563 - val_loss: 2082.3135 - val_mean_absolute_error: 2082.3135
# Epoch 498/500
# 1/4 [======>.......................] - ETA: 0s - loss: 444.5768 - mean_absolute_error: 444.5768
# Epoch 498: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 17ms/step - loss: 261.5018 - mean_absolute_error: 261.5018 - val_loss: 2070.8123 - val_mean_absolute_error: 2070.8123
# Epoch 499/500
# 1/4 [======>.......................] - ETA: 0s - loss: 161.3915 - mean_absolute_error: 161.3915
# Epoch 499: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 17ms/step - loss: 263.8166 - mean_absolute_error: 263.8166 - val_loss: 2085.1833 - val_mean_absolute_error: 2085.1833
# Epoch 500/500
# 1/4 [======>.......................] - ETA: 0s - loss: 475.6292 - mean_absolute_error: 475.6292
# Epoch 500: val_loss did not improve from 2070.12134
# 4/4 [==============================] - 0s 17ms/step - loss: 283.6295 - mean_absolute_error: 283.6295 - val_loss: 2085.2339 - val_mean_absolute_error: 2085.2339

# %%
y_pred5 = NNmodel.predict(X_test)
print_metrics(Y_test,y_pred5)
# Out:
# Mean Absolute Error: 1825.35
# Mean Squared Error: 5721604.3
# Root Mean Squared Error: 2391.99
# Mean Absolute Percentage Error: 0.15
# R2 score: 0.93

# %% [markdown]
# ### Conclusions
# 1. This problem statement was identified as Regression problem.
# 2. Used several regression models to predict the price of the cars with least error.
# 3. The Multiple Linear Regression, Decision Tree Regression, Random Forest Regression and XGBRegression performs very well on the training as well as test sets with Model scores of `92.75%`, `88.2%`, `93.78%` and `92.45%` respectively.
# 4. Among all models the Random Forest Regression technique performs best, but the difference is not much. Any of the three models models can be used by the company.
# 5. We also tried regression using Sequential Neural Networks, produced output has a `Root mean square error` value of `2391.99` and `R2 score` of `0.93` which is also a good score.

# %%
plt.figure(figsize=(18,8), dpi = 300)
plt.suptitle("Performance of models on training data", fontsize = 20)
plt.subplot(2,3,1)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred1, color = 'r', label = 'Linear Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,2)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred2, color = 'g', label = 'Decision Tree Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,3)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred3, color = 'b', label = 'Random Forest Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,4)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred4, color = 'y', label = 'XGBooster Regression Model')
plt.xlabel('Price')
plt.legend()

plt.subplot(2,3,5)
plt.plot(Y_test,Y_test)
plt.scatter(Y_test,y_pred5, color = 'violet', label = 'Neural Network based Regression Model')
plt.xlabel('Price')
plt.legend()

plt.show()
